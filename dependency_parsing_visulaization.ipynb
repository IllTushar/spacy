# %%
import spacy
from spacy import displacy

# %%
nlp = spacy.load('en_core_web_sm')

# %%
doc = nlp('Brexanolone may increase the excretion rate of Aminophylline which could result in a U.K lower serum level and potentially a reduction in efficacy.')

# %%
displacy.render(doc,style='dep',jupyter=True,options={"compact":True,"distance":110})
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="f7f39cd3debc414bb15eb04bf8a068a6-0" class="displacy" width="2580" height="412.0" direction="ltr" style="max-width: none; height: 412.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="322.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">Brexanolone</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="322.0">
#     <tspan class="displacy-word" fill="currentColor" x="160">may</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="160">AUX</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="322.0">
# ...
